# %% [markdown]
# <a href="https://colab.research.google.com/github/robitussin/CCADMACL_EXERCISES/blob/main/Exercise3b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 3B
#
# In this exercise, you will explore how the DBSCAN clustering algorithm identifies dense groups and outliers in the Pokémon statistics dataset. You will analyze the dataset, scale features, determine DBSCAN parameters, run DBSCAN, and interpret the clustering results.

# %%
import kagglehub
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

# %%
# Download latest version
path = kagglehub.dataset_download("abcsds/pokemon")
print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'pokemon' dataset.
# Path to dataset files: /kaggle/input/pokemon

# %%
if os.path.isdir(path):
  print(True)

contents = os.listdir(path)
contents

mydataset = path + "/" + contents[0]
mydataset


df = pd.read_csv(mydataset)
# Out:
# True

# %% [markdown]
# ## 1. Load the Dataset (8 pts)
#
# Load the Pokémon dataset into a pandas DataFrame.

# %% [markdown]
# Show the first five rows (3 pts)

# %%
display(df.head())
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# How many Pokémon are in the dataset? (2 pts)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df.shape[0]
# Out:
# 800

# %% [markdown]
# List all columns available (3 pts)

# %%
display(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ## 2: Select Features & Clean the Data (8 pts)
#
# Select the numeric features needed for clustering (HP, Attack, Defense, Sp. Atk, Sp. Def, Speed). (3 pts)

# %%
features = ["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]
data_features = df[features]
data_features.head()
# Out:
#    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0  45      49       49       65       65     45
# 1  60      62       63       80       80     60
# 2  80      82       83      100      100     80
# 3  80     100      123      122      120     80
# 4  39      52       43       60       50     65

# %% [markdown]
# Are there any missing values? (2 pts)

# %%
df.isna().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %% [markdown]
# If missing values exist, describe how you handled them (3 pts)

# %%
# The 'Type 2' column contains missing values, but it was not selected as a feature for clustering.
# Therefore, the missing values are handled by exclusion from the feature set.

# %%
df["Type 2"] = df["Type 2"].fillna("none")
print(df["Type 2"].value_counts())
df.info()
# Out:
# Type 2
# none        386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ice          14
# Rock         14
# Water        14
# Ghost        14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      800 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# # 3. Scale the Features (10 pts)
#
# Apply StandardScaler to the selected features.
#
# Show the transformed feature sample (e.g., first 5 rows) (10 pts)

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(data_features)

scaled_df = pd.DataFrame(scaled_features, columns=data_features.columns)
scaled_df.head()
# Out:
#          HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# 0 -0.950626 -0.924906 -0.797154 -0.239130 -0.248189 -0.801503
# 1 -0.362822 -0.524130 -0.347917  0.219560  0.291156 -0.285015
# 2  0.420917  0.092448  0.293849  0.831146  1.010283  0.403635
# 3  0.420917  0.647369  1.577381  1.503891  1.729409  0.403635
# 4 -1.185748 -0.832419 -0.989683 -0.392027 -0.787533 -0.112853

# %% [markdown]
# ## 4. Determine a Suitable eps Value (10 pts)

# %% [markdown]
# Using k = 4:
# Compute the distance to the 4th nearest neighbor for each Pokémon (6 pts)

# %%
neighbors = NearestNeighbors(n_neighbors=4)
neighbors_fit = neighbors.fit(scaled_df)
distances, _ = neighbors.kneighbors(scaled_df)

k_distances = np.sort(distances[:, 3])
plt.plot(k_distances)
plt.xlabel('Points sorted by distance')
plt.ylabel('4th Nearest Neighbor Distance')
plt.title('k-distance Graph for DBSCAN')
plt.show()

# %% [markdown]
# What is your chosen eps based on the "elbow"? (2 pts)

# %%
y = np.array(k_distances)
x = np.arange(len(y))

p1 = np.array([x[0], y[0]])
p2 = np.array([x[-1], y[-1]])

points = np.vstack((x, y)).T
points_3d = np.hstack([points, np.zeros((points.shape[0], 1))])
p1_3d = np.append(p1, 0)
p2_3d = np.append(p2, 0)


line_vector = p2_3d - p1_3d
point_vectors = p1_3d - points_3d
cross_products = np.cross(line_vector, point_vectors)
norm_cross_products = np.linalg.norm(cross_products, axis=1)
norm_line_vector = np.linalg.norm(line_vector)

distances = norm_cross_products / norm_line_vector

elbow_index = np.argmax(distances)
optimal_eps = y[elbow_index]

print("Optimal eps:", optimal_eps)

if 1.4 <= optimal_eps <= 2.0:
    print("Accepted eps:", optimal_eps)
else:
    print("Fallback to visual range")
# Out:
# Optimal eps: 1.5248638064269173
# Accepted eps: 1.5248638064269173

# %% [markdown]
# One-sentence explanation of your reasoning (2 pts)

# %%
# The optimal epsilon (eps) value of 1.5248638064269173 is the maximum distance for two points to be considered neighbors, derived from the 'elbow' point in the k-distance graph to effectively identify clusters.

# %% [markdown]
# ## 5. Run DBSCAN (10 points)
#
# Run DBSCAN using your chosen eps and min_samples

# %% [markdown]
# How many clusters did DBSCAN find? (4 pts)

# %%
min_samples = [4, 6, 8, 10, 12, 15]

for min_sample in min_samples:
    db = DBSCAN(eps=1.5, min_samples=min_sample, metric="euclidean")
    db.fit(scaled_df)
    labels = db.labels_
    n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
    print(f"min_samples={min_sample}: clusters={n_clusters}")
# Out:
# min_samples=4: clusters=1
# min_samples=6: clusters=2
# min_samples=8: clusters=1
# min_samples=10: clusters=1
# min_samples=12: clusters=1
# min_samples=15: clusters=1

# %%
#min_samples = 6 has 2 clusters

# %% [markdown]
# How many Pokémon were labeled as noise? (4 pts)

# %%
min_samples_list = [6]
eps = 1.5

for min_samples in min_samples_list:
    db = DBSCAN(eps=eps, min_samples=min_samples, metric="euclidean")
    db.fit(scaled_df)
    labels = db.labels_
    n_noise = list(labels).count(-1)
    print(f"min_samples={min_samples}: noise points = {n_noise}")
# Out:
# min_samples=6: noise points = 44

# %% [markdown]
# Show the unique labels output by DBSCAN (2 pts)

# %%
print("Unique labels:", np.unique(labels))
# Out:
# Unique labels: [-1  0  1]

# %% [markdown]
# ## 6. Attach Cluster Labels to the Original Dataset (7 points)

# %% [markdown]
# Add the cluster labels back to the original DataFrame (3 pts)

# %%
df['cluster'] = db.labels_

# %% [markdown]
# Show the first 10 rows including the cluster label (4 pts)

# %%
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire    none    309  39      52       43
# 5  5                 Charmeleon   Fire    none    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water    none    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  cluster
# 0       65       65     45           1      False        0
# 1       80       80     60           1      False        0
# 2      100      100     80           1      False        0
# 3      122      120     80           1      False        0
# 4       60       50     65           1      False        0
# 5       80       65     80           1      False        0
# 6      109       85    100           1      False        0
# 7      130       85    100           1      False        0
# 8      159      115    100           1      False        0
# 9       50       64     43           1      False        0

# %% [markdown]
# ## 7. Explore the Clusters (12 points)
#
# For each cluster:

# %% [markdown]
# How many Pokémon does it contain? (4 pts)

# %%
df["cluster"].value_counts()
# Out:
# cluster
#  0    750
# -1     44
#  1      6
# Name: count, dtype: int64

# %% [markdown]
# What are the average Attack, Defense, and Speed? (4 pts)

# %%
df.groupby("cluster")[["Attack", "Defense", "Speed"]].mean()
# Out:
#              Attack     Defense      Speed
# cluster
# -1       104.545455   88.909091  73.886364
#  0        77.665333   72.318667  68.068000
#  1        58.666667  153.833333  53.333333

# %% [markdown]
# Compare the clusters: What differences do you notice? (4 pts)

# %%
# Cluster 1 consists of high-defense but slow and low-attack Pokémon, suggesting tank-type or defensive builds.

# Cluster 2 represents balanced Pokémon with moderate attack, defense, and speed.

# Outlier contains Pokemon with high attack and speed but less consistent characteristics, which likely did not fit well into the main clusters.

# %% [markdown]
# ## 8. Identify Outliers (10 points)

# %% [markdown]
# List all Pokémon labeled as noise (cluster = -1) (4 pts)

# %%
df[df["cluster"] == -1]
df[df["cluster"] == -1]["Name"]
# Out:
# 19       BeedrillMega Beedrill
# 44                  Jigglypuff
# 71       AlakazamMega Alakazam
# 87         SlowbroMega Slowbro
# 103                       Onix
# 121                    Chansey
# 155                    Snorlax
# 163        MewtwoMega Mewtwo X
# 164        MewtwoMega Mewtwo Y
# 196      AmpharosMega Ampharos
# 217                  Wobbuffet
# 224        SteelixMega Steelix
# 230                    Shuckle
# 232    HeracrossMega Heracross
# 261                    Blissey
# 269                      Lugia
# 313                    Slaking
# 316                   Shedinja
# 321                   Hariyama
# 333          AggronMega Aggron
# 350                    Wailmer
# 351                    Wailord
# 354      CameruptMega Camerupt
# 414                   Regirock
# 415                     Regice
# 422        KyogrePrimal Kyogre
# 424      GroudonPrimal Groudon
# 426      RayquazaMega Rayquaza
# 428         DeoxysNormal Forme
# 429         DeoxysAttack Forme
# 431          DeoxysSpeed Forme
# 454                  Rampardos
# 473                   Drifblim
# 488                    Happiny
# 495                   Munchlax
# 511    AbomasnowMega Abomasnow
# 527        GalladeMega Gallade
# 544      GiratinaAltered Forme
# 616         DarmanitanZen Mode
# 655                  Alomomola
# 676                  Cryogonal
# 750       AegislashBlade Forme
# 796        DiancieMega Diancie
# 798         HoopaHoopa Unbound
# Name: Name, dtype: object

# %% [markdown]
# Are many of them legendary? (3 pts)

# %%
legendary_outliers = df[(df["cluster"] == -1) & (df["Legendary"] == True)]
print(legendary_outliers[['Name', 'Legendary', 'cluster']])
print(f"Number of legendary outliers: {legendary_outliers.shape[0]}")
# Out:
#                       Name  Legendary  cluster
# 163    MewtwoMega Mewtwo X       True       -1
# 164    MewtwoMega Mewtwo Y       True       -1
# 269                  Lugia       True       -1
# 414               Regirock       True       -1
# 415                 Regice       True       -1
# 422    KyogrePrimal Kyogre       True       -1
# 424  GroudonPrimal Groudon       True       -1
# 426  RayquazaMega Rayquaza       True       -1
# 428     DeoxysNormal Forme       True       -1
# 429     DeoxysAttack Forme       True       -1
# 431      DeoxysSpeed Forme       True       -1
# 544  GiratinaAltered Forme       True       -1
# 796    DiancieMega Diancie       True       -1
# 798     HoopaHoopa Unbound       True       -1
# Number of legendary outliers: 14

# %%
# There are 14 legendary pokemons

# %% [markdown]
# Explain why DBSCAN might classify them as outliers (3 pts)

# %%
# DBSCAN marks these Pokemon as outliers because they do not have enough nearby neighbors within the chosen eps value, meaning their stats are too different from most Pokémon and they fall in low-density areas of the data.

# %% [markdown]
# ## 9. Interpret the Clustering Results (25 points)
# Write a short interpretation (4–6 sentences).
# Discuss:

# %%
types_long = pd.concat([
    df[["cluster", "Type 1"]].rename(columns={"Type 1": "Type"}),
    df[["cluster", "Type 2"]].rename(columns={"Type 2": "Type"})
]).dropna()

types_no_none_values = types_long[types_long["Type"] != "None"]

types_no_none_values.groupby(["cluster", "Type"]).size().sort_values(ascending=False)
# Out:
# cluster  Type
#  0       none        362
#          Water       121
#          Flying       98
#          Normal       95
#          Grass        94
#          Psychic      77
#          Bug          68
#          Ground       63
#          Poison       61
#          Fire         61
#          Dark         50
#          Rock         50
#          Electric     49
#          Fighting     49
#          Dragon       47
#          Steel        42
#          Ghost        41
#          Fairy        37
#          Ice          35
# -1       none         22
#          Psychic      12
#          Normal        7
#          Water         5
#          Rock          5
#          Fighting      4
#          Ghost         4
#          Ground        4
#          Bug           4
#  1       Steel         4
# -1       Steel         3
#  1       Rock          3
# -1       Ice           3
#          Fire          3
#          Dragon        3
#          Flying        3
#          Fairy         2
#  1       none          2
# -1       Grass         1
#          Dark          1
#          Electric      1
#          Poison        1
#  1       Fairy         1
#          Ghost         1
#          Psychic       1
# dtype: int64

# %% [markdown]
# What types of Pokémon grouped together (5 pts)

# %%
# (Cluster 0) The Pokémon grouped together in Cluster 0 are mostly common types such as Water, Flying, Normal, Grass, Psychic, Bug, Ground, Poison, Fire, Electric, Rock, Fighting, Dark, Dragon, Steel, Ghost, Fairy, and Ice. Many of these Pokémon also do not have a secondary type, which explains why they are clustered closely together.

# %%
# The outliers include Psychic, Dark, and Dragon-type Pokémon, as well as some Mega Pokémon. DBSCAN classified them as outliers because they have very high overall base stats, placing them in low-density areas that do not fit well into the main clusters.

# %%
# Cluster 1 is mainly composed of Rock- and Steel-type Pokémon, which generally have higher Defense stats. DBSCAN grouped these Pokémon together because they share similar high-defense characteristics.

# %% [markdown]
# Whether the clusters make intuitive sense (10 pts)

# %%
#cluster 0 the common type of pokemons
#cluster 1 the group of pokemons that has high defense stats
#outliers the group of some mega pokemon that dbscan classified it outliers because they have very high base stats

# %% [markdown]
# What the noise points reveal about DBSCAN (5 pts)

# %%
# The noise points show that DBSCAN is effective at finding true outliers, or data points that do not belong to any dense region. This indicates that these Pokémon are statistically different from the main clusters because they do not have enough nearby neighbors within the chosen eps distance.

# %% [markdown]
# What stat patterns you discovered (5 pts)

# %%
# The analysis revealed clear stat patterns among the clusters. Cluster 1 includes Pokémon with very high Defense but lower Attack and Speed, suggesting more defensive types. Cluster 0 contains Pokémon with balanced and moderate stats overall. The outliers (Cluster -1) generally have higher Attack and total stats, indicating powerful or specialized Pokémon that differ significantly from the main clusters.
